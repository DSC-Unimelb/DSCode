# %%
#Run this command to install seaborn

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#sns has a plethora preloaded datasets, we'll be using one of them for the workshop today

diamonds = sns.load_dataset("diamonds")

# %%
#remember i mentioned its designed to work well with dataframes

type(diamonds)
# Out:
# pandas.core.frame.DataFrame

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(diamonds['carat'])

# %%
sns.lineplot(x="carat", y="price",
             #hue="clarity",
             data=diamonds)

# %%
sns.scatterplot(x = 'carat', y = 'price', data = diamonds)

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(11.5, 11.5))
#sns.despine(f, left=True, bottom=True)
#clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", #size="depth",
                #palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)

#changing axis uses matplotlib
plt.xlabel("XLabel")
plt.ylabel("YLabel")

f.suptitle("title", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'title')

# %%
corr = data.corr()

# %%
corr
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(corr)

# %%
import numpy as np
np = np.array([1,2,3,3])

# %%
np[1]
# Out:
# 2
